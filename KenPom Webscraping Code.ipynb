# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import json
import requests
from selenium import webdriver
from bs4 import BeautifulSoup, Comment
from collections import defaultdict
import csv
import re

# https://www.youtube.com/watch?v=ODNMNwgtehk&t=319
#https://www.visualnoise.io/nba-shot-data-analytics-visualization-with-python-pandas-and-matplotlib-part-1-the-basics/
#https://www.youtube.com/watch?v=DlaZe46JSaA&t=297s
#https://towardsdatascience.com/make-a-simple-nba-shot-chart-with-python-e5d70db45d0d

# %% [markdown]
# This code scrapes the url for data

# %%
df = pd.read_html('https://web.archive.org/web/20190112035602/https://kenpom.com/index.php?y=2002')

# %%
archived_stats=(df[1])
archived_stats
# Out:
#      Unnamed: 0_level_0   Unnamed: 1_level_0  Unnamed: 2_level_0  \
#                      Rk                 Team                Conf
#      Unnamed: 0_level_2   Unnamed: 1_level_2  Unnamed: 2_level_2
#                      Rk                 Team                Conf
#      Unnamed: 0_level_4   Unnamed: 1_level_4  Unnamed: 2_level_4
#                      Rk                 Team                Conf
#      Unnamed: 0_level_6   Unnamed: 1_level_6  Unnamed: 2_level_6
#                      Rk                 Team                Conf
#      Unnamed: 0_level_8   Unnamed: 1_level_8  Unnamed: 2_level_8
#                      Rk                 Team                Conf
#     Unnamed: 0_level_10  Unnamed: 1_level_10 Unnamed: 2_level_10
#                      Rk                 Team                Conf
#     Unnamed: 0_level_12  Unnamed: 1_level_12 Unnamed: 2_level_12
#                      Rk                 Team                Conf
# ...

# %% [markdown]
# Code saves the data to a blank csv file named 'Data' which is located on the desktop

# %%
#Save df to computer
#Change folder

archived_stats.to_csv(r'C:\Users\s_cri\Desktop\Practice\Practice.csv')

# %% [markdown]
# Delete any extra rows from csv file before moving on to next line

# %% [markdown]
# Code calls the csv file from the desktop and renames it

# %%
# Use 'r' before your normal string. It converts a normal string to a raw string

pt= pd.read_csv(r'C:\Users\s_cri\Desktop\Practice\Practice.csv')
pt.head(25)
# Out:
#     Unnamed: 0   Unnamed: 0_level_0   Unnamed: 1_level_0   Unnamed: 2_level_0  \
# 0          NaN                   Rk                 Team                 Conf
# 1          NaN   Unnamed: 0_level_2   Unnamed: 1_level_2   Unnamed: 2_level_2
# 2          NaN                   Rk                 Team                 Conf
# 3          NaN   Unnamed: 0_level_4   Unnamed: 1_level_4   Unnamed: 2_level_4
# 4          NaN                   Rk                 Team                 Conf
# 5          NaN   Unnamed: 0_level_6   Unnamed: 1_level_6   Unnamed: 2_level_6
# 6          NaN                   Rk                 Team                 Conf
# 7          NaN   Unnamed: 0_level_8   Unnamed: 1_level_8   Unnamed: 2_level_8
# 8          NaN                   Rk                 Team                 Conf
# 9          NaN  Unnamed: 0_level_10  Unnamed: 1_level_10  Unnamed: 2_level_10
# 10         NaN                   Rk                 Team                 Conf
# ...

# %% [markdown]
# This code replaces the - with and in the W-L column

# %%
# pt['W-L'] = pt19['W-L'].str.replace('-',' and ')

# pt

# %% [markdown]
# This code splits the Wins/Losses into two columms

# %%
# pt[['Wins', 'Losses']] = pt['W-L'].str.split('and', expand=True)
# # display the dataframe
# pt

# %% [markdown]
# This code saves the new data into a csv file located on the desktop
#
# ##Change to new file path

# %%
#pt.to_csv(r'C:\Users\s_cri\Downloads\group_2 (2)\KenPom\pre_tourney_2002.csv')
