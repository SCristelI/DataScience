# %% [markdown]
# Cristel Irwin

# %% [markdown]
# Notes:
#     API's: An application programming interface is a connection between computers or between computer programs.
#     Also know as communication protocol between programs. API helps information transferal between applications.
#
#   Hypertext Transfer Protocol (http:) is an application-layer protocol for transmitting hypermedia documents, such as HTML
#
#   API example: https://seeclickfix.com/ allows developers to create applications using data from the site
#   for developers http://dev.seeclickfix.com/, https://developer.twitter.com/en, https://developer.linkedin.com/, https://developers.facebook.com/, wikipedia (https://pypi.org/project/Wikipedia-API/), rapidapi.com

# %% [markdown]
# ## API Basics

# %%
# First step is to Import json
import json
import requests #libraries to get info from internet

# %%
url = "https://seeclickfix.com/api/v2/places?address=Los%20Angeles,%20CA"

# %%
response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
if response == 200:
    print("It is equal")
else:
    print("Not equal")
# Out:
# Not equal

# %%
response.json()
# Out:
# {'places': [{'id': 1771,
#    'name': 'Los Angeles',
#    'url_name': 'los-angeles',
#    'county': 'Los Angeles',
#    'state': 'CA',
#    'center': {'type': 'Point',
#     'coordinates': [-118.41170427954205, 34.107010786614204]},
#    'place_type': 'City',
#    'url': 'https://seeclickfix.com/api/v2/places/1771',
#    'html_url': 'https://seeclickfix.com/los-angeles',
#    'html_report_url': 'https://seeclickfix.com/los-angeles/report'},
#   {'id': 74887,
#    'name': 'Los Angeles County',
#    'url_name': 'los-angeles-county',
#    'county': None,
#    'state': 'CA',
#    'center': {'type': 'Point',
#     'coordinates': [-118.21728546056828, 34.358746092753236]},
#    'place_type': 'County',
#    'url': 'https://seeclickfix.com/api/v2/places/74887',
#    'html_url': 'https://seeclickfix.com/los-angeles-county',
#    'html_report_url': 'https://seeclickfix.com/los-angeles-county/report'},
#   {'id': 26189,
#    'name': 'Civic Center-Little Tokyo',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
my_dict = response.json() #store json file

# %%
my_dict.keys() #analyze json file
# Out:
# dict_keys(['places', 'metadata'])

# %%
my_dict["places"]
# Out:
# [{'id': 1771,
#   'name': 'Los Angeles',
#   'url_name': 'los-angeles',
#   'county': 'Los Angeles',
#   'state': 'CA',
#   'center': {'type': 'Point',
#    'coordinates': [-118.41170427954205, 34.107010786614204]},
#   'place_type': 'City',
#   'url': 'https://seeclickfix.com/api/v2/places/1771',
#   'html_url': 'https://seeclickfix.com/los-angeles',
#   'html_report_url': 'https://seeclickfix.com/los-angeles/report'},
#  {'id': 74887,
#   'name': 'Los Angeles County',
#   'url_name': 'los-angeles-county',
#   'county': None,
#   'state': 'CA',
#   'center': {'type': 'Point',
#    'coordinates': [-118.21728546056828, 34.358746092753236]},
#   'place_type': 'County',
#   'url': 'https://seeclickfix.com/api/v2/places/74887',
#   'html_url': 'https://seeclickfix.com/los-angeles-county',
#   'html_report_url': 'https://seeclickfix.com/los-angeles-county/report'},
#  {'id': 26189,
#   'name': 'Civic Center-Little Tokyo',
#   'url_name': 'civic-center-little-tokyo',
# ...

# %%
my_first_place = my_dict["places"][0] #takes first element

# %%
type(my_first_place)
# Out:
# dict

# %%
my_first_place.keys()
# Out:
# dict_keys(['id', 'name', 'url_name', 'county', 'state', 'center', 'place_type', 'url', 'html_url', 'html_report_url'])

# %%
my_first_place
# Out:
# {'id': 1771,
#  'name': 'Los Angeles',
#  'url_name': 'los-angeles',
#  'county': 'Los Angeles',
#  'state': 'CA',
#  'center': {'type': 'Point',
#   'coordinates': [-118.41170427954205, 34.107010786614204]},
#  'place_type': 'City',
#  'url': 'https://seeclickfix.com/api/v2/places/1771',
#  'html_url': 'https://seeclickfix.com/los-angeles',
#  'html_report_url': 'https://seeclickfix.com/los-angeles/report'}

# %%
my_dict
# Out:
# {'places': [{'id': 1771,
#    'name': 'Los Angeles',
#    'url_name': 'los-angeles',
#    'county': 'Los Angeles',
#    'state': 'CA',
#    'center': {'type': 'Point',
#     'coordinates': [-118.41170427954205, 34.107010786614204]},
#    'place_type': 'City',
#    'url': 'https://seeclickfix.com/api/v2/places/1771',
#    'html_url': 'https://seeclickfix.com/los-angeles',
#    'html_report_url': 'https://seeclickfix.com/los-angeles/report'},
#   {'id': 74887,
#    'name': 'Los Angeles County',
#    'url_name': 'los-angeles-county',
#    'county': None,
#    'state': 'CA',
#    'center': {'type': 'Point',
#     'coordinates': [-118.21728546056828, 34.358746092753236]},
#    'place_type': 'County',
#    'url': 'https://seeclickfix.com/api/v2/places/74887',
#    'html_url': 'https://seeclickfix.com/los-angeles-county',
#    'html_report_url': 'https://seeclickfix.com/los-angeles-county/report'},
#   {'id': 26189,
#    'name': 'Civic Center-Little Tokyo',
# ...

# %%
a_file_to_save = open("seeclickfix_my_version_of_it.json", "w") #creates json file for writing, saves it to folder in jupyter and computer

# %%
json.dump(my_dict, a_file_to_save, indent=4)

# %%
a_file_to_save.close()

# %% [markdown]
# # Practice with https://seeclickfix.com/api/v2 returns a json file
#
# {"links":{"profile_url":"https://seeclickfix.com/api/v2/profile","issues_url":"https://seeclickfix.com/api/v2/issues","issues_form_url":"https://seeclickfix.com/api/v2/issues/new{?lat,lng}","issue_url":"https://seeclickfix.com/api/v2/issues/{issue_id}","users_url":"https://seeclickfix.com/api/v2/organizations/users{?query,email}","notices_url":"https://seeclickfix.com/api/v2/notices","locales_url":"https://seeclickfix.com/api/v2/locales","time_zones_url":"https://seeclickfix.com/api/v2/time_zones"}}

# %% [markdown]
# #Using json beautifier https://jsonbeautifier.org/
#
# {
#   "links": {
#     "profile_url": "https://seeclickfix.com/api/v2/profile",
#     "issues_url": "https://seeclickfix.com/api/v2/issues",
#     "issues_form_url": "https://seeclickfix.com/api/v2/issues/new{?lat,lng}",
#     "issue_url": "https://seeclickfix.com/api/v2/issues/{issue_id}",
#     "users_url": "https://seeclickfix.com/api/v2/organizations/users{?query,email}",
#     "notices_url": "https://seeclickfix.com/api/v2/notices",
#     "locales_url": "https://seeclickfix.com/api/v2/locales",
#     "time_zones_url": "https://seeclickfix.com/api/v2/time_zones"
#   }
# }

# %% [markdown]
# Work with dev.seeclickfix.com
#
#     https://seeclickfix.com/open311/v2/requests.json?lat=41.307153&long=-72.925791
#
#
#         [
#   {
#     "description": "Please have someone clean top of bus stop",
#     "address": "55 Church St New Haven CT 06510, United States",
#     "lat": 41.3049839,
#     "service_request_id": 12006653,
#     "requested_datetime": "2022-03-10T11:32:04-05:00",
#     "long": -72.925991,
#     "service_code": 1966,
#     "status": "closed",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-10T12:27:53-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Trash & Recycling",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBelltWHc9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--cabf6670ec903afab2b8f83be0c9c4f5e21b027c/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/image.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "There will be a temporary parking ban posted on on the odd side of Chapel St at 1021 Chapel St to destroy water service on 03/10/2022, from 9:00AM - 4:00PM. Permit #RO-21-00498. Approximate end date is 03/10/2022",
#     "address": "41.3073458700001 -72.929055833",
#     "lat": 41.3073458700001,
#     "service_request_id": 11988619,
#     "requested_datetime": "2022-03-09T15:11:32-05:00",
#     "long": -72.929055833,
#     "service_code": 21532,
#     "status": "open",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-09T15:11:34-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Neighborhood News",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Overflowing dumpster behind 754 Chapel Street (parking lot at 300 State St). This dumpster was the site of a fire in April 2019 which caused the closure of Chapel Street and the response of 27 firefighters on scene and multiple trucks. \n\nhttps://www.sfchronicle.com/news/article/Dumpster-fire-results-in-heavy-widespread-smoke-13777489.php#photo-17246902\n\nhttps://www.newhavenindependent.org/index.php/article/fire_post_office/\n\nhttps://www.wtnh.com/news/dumpster-fire-fills-building-with-smoke-closes-roads-in-downtown-new-haven/\n",
#     "address": "754 Chapel St New Haven, CT, 06510, USA",
#     "lat": 41.3045949630023,
#     "service_request_id": 11977695,
#     "requested_datetime": "2022-03-08T15:49:23-05:00",
#     "long": -72.9233623814508,
#     "service_code": 1251,
#     "status": "open",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-09T15:34:37-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Private Property Issue",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBd2dEWHc9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--ab08050b82ca986f392de603fe8a80f09f31b4ca/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJY0c1bkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--a97fc2b9573eb2bdd92c5c7b4116262444f87298/Snipaste_2022-03-08_15-32-24.png",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "My husband had an extremely close call with a car this morning, Elm and Church st.\nHe walks to work (Yale) and car came out of no where, sped through cross walk-husband was so upset-we have a five month old at home he was so started he was afraid it was the end. \nThis is becoming a weekly occurrence for those who walk/bike in this city. We live East Rock--5 pedestrians we're hit last month The Independent reported. I have lived in all sections of the city from the Hill to Tre, now on State Street in East Rock. It takes me forever to cross State---with a baby---Drivers do not care--it is your job to figure out a way to make them care. I almost lost my husband today.\nDrivers need to respect the roads.",
#     "address": "121 Elm St New Haven, CT, 06510, USA",
#     "lat": 41.3084273813031,
#     "service_request_id": 11969945,
#     "requested_datetime": "2022-03-07T12:12:45-05:00",
#     "long": -72.9241494834423,
#     "service_code": null,
#     "status": "open",
#     "zipcode": "06511",
#     "updated_datetime": "2022-03-07T12:53:57-05:00",
#     "agency_responsible": null,
#     "service_name": null,
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "just thought the sign was worth out for temple street",
#     "address": "Elm St & Temple St New Haven, CT 06511, USA",
#     "lat": 41.3087121756862,
#     "service_request_id": 11965868,
#     "requested_datetime": "2022-03-06T15:06:47-05:00",
#     "long": -72.9255194216967,
#     "service_code": 373,
#     "status": "open",
#     "zipcode": "06511",
#     "updated_datetime": "2022-03-06T15:07:59-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Signs",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBK0xWWGc9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--38eb17824ffc8f7f6be66b89abc68e1ede3605cb/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/img-image-8482074160650938352500.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "There will be a temporary parking ban posted on on the odd side of Elm St at 59 Elm St for a moving truck on 03/05/2022. Approximate end date is 03/05/2022",
#     "address": "41.3077612640001 -72.922859133",
#     "lat": 41.3077612640001,
#     "service_request_id": 11959054,
#     "requested_datetime": "2022-03-04T12:45:31-05:00",
#     "long": -72.922859133,
#     "service_code": 21532,
#     "status": "open",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-04T12:45:31-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Neighborhood News",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Buzzuti Trash has been collecting trash at 4:20 or so each morning outside our building.  ",
#     "address": "85 Church St New Haven, CT 06510, USA",
#     "lat": 41.3053728,
#     "service_request_id": 11943405,
#     "requested_datetime": "2022-03-01T14:25:30-05:00",
#     "long": -72.9259105,
#     "service_code": 33955,
#     "status": "open",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-01T15:25:17-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Private Trash Haulers",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "There is no way for pedestrians to cross 3 out of 4 legs of this intersection (the exception being the west crossing when Elm is stopped). Adding pedestrian heads is what should be done, but the cheaper solution would be to eliminate 2 of the 3 traffic lanes on Elm (replace with 2 way painted bike lanes) and designalize the intersection. No ped heads needed, just 4 stop signs.",
#     "address": "Elm St & Orange St New Haven, CT, 06510, USA",
#     "lat": 41.3076463594743,
#     "service_request_id": 11939354,
#     "requested_datetime": "2022-02-28T20:59:35-05:00",
#     "long": -72.9226469853893,
#     "service_code": 51,
#     "status": "closed",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-01T14:31:54-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Traffic Signal / Pedestrian Signal",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBenRzWGc9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--9877430bba8f1c0097e07a99e7f2a646bb50184c/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/20220210_120430.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "This strip of bus stop needs to be cleared of snow and ice.",
#     "address": "250 Temple St New Haven CT 06511, United States",
#     "lat": 41.3076679269237,
#     "service_request_id": 11932803,
#     "requested_datetime": "2022-02-27T16:16:41-05:00",
#     "long": -72.926310757243,
#     "service_code": 8516,
#     "status": "open",
#     "zipcode": "06511",
#     "updated_datetime": "2022-02-28T12:46:25-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "SNOW RELATED",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBMnBTWGc9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--e8c0fbeec82eff9338f535c2cbb10b95624e756b/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/image.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Sidewalk not shoveled   ",
#     "address": "135 Orange St New Haven CT 06510, United States",
#     "lat": 41.3055878312533,
#     "service_request_id": 11929471,
#     "requested_datetime": "2022-02-26T12:57:13-05:00",
#     "long": -72.9238418597743,
#     "service_code": 1249,
#     "status": "closed",
#     "zipcode": "06511",
#     "updated_datetime": "2022-03-03T14:37:35-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Public Space, Streets and Drains",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBOWhFWGc9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--e4bec2938c6b36170e5512847b9fb40e4a2fee6f/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/image.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Dear New Haven fixers, as the weather gets warmer, the illegally modified motorcycles start to ply the city streets, revving their engines, damaging eardrums, scaring away sidewalk diners and tourists, setting off car alarms etc. Would New Haven consider installing (and using) noise monitoring cameras, as Knoxville, Tennessee has done? Here's the story: https://noisefree.org/knoxville-tennessee-wins-healthy-soundscape-award-for-installing-noise-monitoring-camera-downtown/ Thanks for considering.",
#     "address": "New Haven CT, USA",
#     "lat": 41.30801,
#     "service_request_id": 11925871,
#     "requested_datetime": "2022-02-25T12:51:22-05:00",
#     "long": -72.92432,
#     "service_code": 36793,
#     "status": "closed",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-09T17:22:44-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Environmental Health Concerns (Non-Covid Related)",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "These trash cans have lived on the street for months  It is my understanding that the landlord (pike int) needs to store them inside  Can the city please help with this situation  A new business is moving in and I'm sure they won't be happy with this",
#     "address": "837 Chapel St New Haven CT 06510, United States",
#     "lat": 41.3057412213786,
#     "service_request_id": 11921204,
#     "requested_datetime": "2022-02-24T13:05:00-05:00",
#     "long": -72.9249188000462,
#     "service_code": 32782,
#     "status": "closed",
#     "zipcode": "06510",
#     "updated_datetime": "2022-03-10T11:16:41-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "PUBLIC SPACE ENFORCEMENT",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBejBrWGc9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--549f8e2a380b88125f0d6b42754311e97429a5d8/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/image.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "There will be a temporary parking ban posted on on the even side of Church St at 234 Church St to repair utility vaults on 02/23/2022, from 9:00AM - 4:00PM. Permit #OB-21-00591. Approximate end date is 02/23/2022",
#     "address": "41.3093381370001 -72.9234564509999",
#     "lat": 41.3093381370001,
#     "service_request_id": 11910826,
#     "requested_datetime": "2022-02-22T14:40:23-05:00",
#     "long": -72.9234564509999,
#     "service_code": 21532,
#     "status": "closed",
#     "zipcode": "06511",
#     "updated_datetime": "2022-03-01T09:47:02-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Neighborhood News",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Need trash can",
#     "address": "186-198 Church St New Haven, CT, 06510, USA",
#     "lat": 41.3080193401415,
#     "service_request_id": 11908425,
#     "requested_datetime": "2022-02-22T09:19:18-05:00",
#     "long": -72.9243278503418,
#     "service_code": 1966,
#     "status": "closed",
#     "zipcode": "06510",
#     "updated_datetime": "2022-02-23T09:08:00-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Trash & Recycling",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Noise from Gotham City Cafe is really beyond the pale on Friday and Saturday nights. There are so many cars gunning their engines very late at night -- especially so around the time that the bar lets out, but I am hearing it now at midnight. It wakes me up, makes it hard to sleep on weekends. It is way louder than 45 decibels. None of these cars seem to have mufflers. I live on Crown Street. ",
#     "address": "84 Orange St New Haven, CT, 06510, USA",
#     "lat": 41.30496101049,
#     "service_request_id": 11896877,
#     "requested_datetime": "2022-02-19T00:17:00-05:00",
#     "long": -72.9249609694467,
#     "service_code": 36793,
#     "status": "closed",
#     "zipcode": "06510",
#     "updated_datetime": "2022-02-22T18:06:15-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Environmental Health Concerns (Non-Covid Related)",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Every. Single. Day. ",
#     "address": "200 Orange St New Haven, CT 06510, USA",
#     "lat": 41.3071106,
#     "service_request_id": 11893806,
#     "requested_datetime": "2022-02-18T10:06:47-05:00",
#     "long": -72.9234992,
#     "service_code": 121,
#     "status": "open",
#     "zipcode": "06510",
#     "updated_datetime": "2022-02-18T10:07:08-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Parking Violation/Abandoned Auto",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBN3kyWFE9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--14bb85f8b19cfc0dd72c0782985ba6188259f644/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/img-image-249441924456936199217356.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "There are several lights in the alleyway between The Taft and Shubert Theater (between College Street and the Temple Street Plaza) that are not working properly.  Either the lights are out, or the light flickers.  This creates a safety hazard for pedestrians passing through as well as an annoyance for tenants facing in that direction in their apartments at The Taft.",
#     "address": "265 College St New Haven, CT, 06510, USA",
#     "lat": 41.3068069989359,
#     "service_request_id": 11888949,
#     "requested_datetime": "2022-02-17T11:16:00-05:00",
#     "long": -72.9287149724219,
#     "service_code": 124,
#     "status": "open",
#     "zipcode": "06510",
#     "updated_datetime": "2022-02-17T11:16:09-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Street Lamp",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "There will be a temporary parking ban posted on on both sides of Church St at 234 Church St for utility maintenance on 02/16/2022, from 9:00AM - 4:00PM. Permit #OB-21-00594. Approximate end date is 02/16/2022",
#     "address": "41.309605327 -72.9230586259999",
#     "lat": 41.309605327,
#     "service_request_id": 11878642,
#     "requested_datetime": "2022-02-15T13:02:13-05:00",
#     "long": -72.9230586259999,
#     "service_code": 21532,
#     "status": "closed",
#     "zipcode": "06510",
#     "updated_datetime": "2022-02-18T13:48:59-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Neighborhood News",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Board of Alders legal notices include a line like, \"If you wish to present testimony at the meeting, you must register in advance at https://bit.ly/[xyz] or by calling (203) 946‑6483 or emailing publictestimony@newhavenct.gov before 2:00 pm on the day of the meeting.\"\n\nHowever, the link is just a Zoom call that is not active until the meeting actually starts (so, not actually a way to submit or register for public comment). I sent an e-mail six days ago to the e-mail address listed and have yet to receive a response. It's also not at all clear whether the testimony itself must be submitted in advance, or if citizens are just meant to give their names to get on a list to testify.\n\nPlease do better at informing the public about how to participate.",
#     "address": "City Hall",
#     "lat": 41.3073800000001,
#     "service_request_id": 11878238,
#     "requested_datetime": "2022-02-15T11:55:30-05:00",
#     "long": -72.92459,
#     "service_code": 374,
#     "status": "open",
#     "zipcode": "06510",
#     "updated_datetime": "2022-02-15T13:30:48-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Other",
#     "media_url": null,
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   },
#   {
#     "description": "Various street lamps along Elm Street are either flickering or not functioning\n\nPlease repair as able ",
#     "address": "143 Elm St New Haven CT 06511, United States",
#     "lat": 41.308975,
#     "service_request_id": 11865431,
#     "requested_datetime": "2022-02-11T23:49:30-05:00",
#     "long": -72.925605,
#     "service_code": 124,
#     "status": "open",
#     "zipcode": "06511",
#     "updated_datetime": "2022-02-23T09:39:17-05:00",
#     "agency_responsible": "City of New Haven",
#     "service_name": "Street Lamp",
#     "media_url": "https://seeclickfix.com/rails/active_storage/representations/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBMlZLWFE9PSIsImV4cCI6bnVsbCwicHVyIjoiYmxvYl9pZCJ9fQ==--d0b69a4f0551462aecbb04a121d36b37570afabe/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaDdDVG9MWm05eWJXRjBTU0lJYW5CbkJqb0dSVlE2RUdGMWRHOWZiM0pwWlc1MFZEb0tjM1J5YVhCVU9ndHlaWE5wZW1WSklndzRNREI0TmpBd0Jqc0dWQT09IiwiZXhwIjpudWxsLCJwdXIiOiJ2YXJpYXRpb24ifX0=--ee2a5b821fe0552ba6053903421e37a595d06845/image.jpg",
#     "expected_datetime": null,
#     "address_id": null,
#     "service_notice": null,
#     "status_notes": null
#   }
# ]

# %% [markdown]
# https://seeclickfix.com/api/v2/issues/new?lat=41.308274&lng=-72.9278835
#
#     {
#   "request_types": [
#     {
#       "title": "General Bus Request/Incident",
#       "id": 4947,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "CT Transit - New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/4947",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=4947&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Covid-19 Complaints",
#       "id": 28110,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "Public Health",
#       "url": "https://seeclickfix.com/api/v2/request_types/28110",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=28110&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Covid Questions - Schools, Daycares, Employers, Businesses",
#       "id": 28113,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "Public Health",
#       "url": "https://seeclickfix.com/api/v2/request_types/28113",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=28113&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Public Health Concerns - Restaurants",
#       "id": 28111,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": true,
#       "organization": "Public Health",
#       "url": "https://seeclickfix.com/api/v2/request_types/28111",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=28111&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Public Health Questions (Non-Covid Related)",
#       "id": 36792,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "Public Health",
#       "url": "https://seeclickfix.com/api/v2/request_types/36792",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=36792&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Environmental Health Concerns (Non-Covid Related)",
#       "id": 36793,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "Public Health",
#       "url": "https://seeclickfix.com/api/v2/request_types/36793",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=36793&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Need Neighbors Support",
#       "id": 28079,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "Public Health",
#       "url": "https://seeclickfix.com/api/v2/request_types/28079",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=28079&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Bicycle Rack Request",
#       "id": 21509,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/21509",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=21509&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Bus Shelters",
#       "id": 22112,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22112",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22112&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Drainage Request",
#       "id": 22193,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22193",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22193&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Graffiti",
#       "id": 122,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/122",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=122&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Health Dept.",
#       "id": 5185,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/5185",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=5185&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Illegal Dumping",
#       "id": 1250,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/1250",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=1250&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Library Issues",
#       "id": 12386,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/12386",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=12386&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "NHFD - Fire Hazard",
#       "id": 22061,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22061",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22061&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "NHFD - Fire Hydrants",
#       "id": 22062,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22062",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22062&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "NHFD - Fire Investigations",
#       "id": 22063,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22063",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22063&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "NHFD - Fire Safety Concern",
#       "id": 22058,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22058",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22058&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "NHFD - Fire Violation",
#       "id": 22059,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22059",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22059&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Parking Meter",
#       "id": 372,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/372",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=372&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Parking Violation/Abandoned Auto",
#       "id": 121,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/121",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=121&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Parks Request",
#       "id": 126,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/126",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=126&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Pavement Markings",
#       "id": 22113,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/22113",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=22113&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Potholes",
#       "id": 116,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/116",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=116&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Private Property Issue",
#       "id": 1251,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/1251",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=1251&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Public Space, Streets and Drains",
#       "id": 1249,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/1249",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=1249&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "SNOW RELATED",
#       "id": 8516,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/8516",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=8516&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Sidewalks and Curb damage",
#       "id": 117,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/117",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=117&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Signs",
#       "id": 373,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/373",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=373&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Street Lamp",
#       "id": 124,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/124",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=124&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Traffic Signal / Pedestrian Signal",
#       "id": 51,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/51",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=51&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Trash & Recycling",
#       "id": 1966,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/1966",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=1966&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Private Trash Haulers",
#       "id": 33955,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/33955",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=33955&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Tree Trimming",
#       "id": 1853,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/1853",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=1853&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Youth & Recreation",
#       "id": 32395,
#       "is_other": false,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "New Haven",
#       "url": "https://seeclickfix.com/api/v2/request_types/32395",
#       "potential_duplicate_issues_url": "https://seeclickfix.com/api/v2/issues?details=true&lat=41.308274&lng=-72.9278835&max_lat=41.309073999999995&max_lng=-72.9270835&min_lat=41.307474&min_lng=-72.92868349999999&per_page=5&request_types=32395&sort=distance&status=open%2Cacknowledged"
#     },
#     {
#       "title": "Post to Neighbors",
#       "id": "other",
#       "is_other": true,
#       "location_required": true,
#       "permit_guest_reporting": true,
#       "private_visibility": false,
#       "organization": "Community",
#       "url": "https://seeclickfix.com/api/v2/request_types/other",
#       "potential_duplicate_issues_url": null
#     }
#   ]
# }
